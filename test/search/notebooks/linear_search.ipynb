# %%
from py_puzzle.search.algorithm import LinearSearch

linear_search = LinearSearch().process()
tgt_value = linear_search["Input"].index(linear_search["Target"])
print(linear_search, "ExpectedOutput: ", tgt_value)
assert linear_search["Output"] == tgt_value
# Out:
# {'Input': [3, 7, 8, 9, 11, 17, 20, 27, 30, 33, 34, 35, 35, 45, 49, 50, 50, 51, 66, 69, 70, 72, 77, 85, 99], 'Target': 8, 'Output': 2} ExpectedOutput:  2
